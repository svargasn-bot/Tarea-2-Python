# %% [markdown]
# # Tarea 2: Procesamiento de Texto con Python
# ### Integrantes:
# * Sebastian Vargas
# * Sebastian Leon
# * Rodrigo Ramirez
#
# **Asignatura:** Taller de Python para Ciencia de Datos

# %% [markdown]
# # Introduccion <a id="0"></a>

# %% [markdown]
# importar bibliotecas.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))
from src import plots

# %% [markdown]
# definir entrada del csv limpio.

# %%
df = pd.read_csv('../data/processed/global_freelancers_processed.csv')

# %% [markdown]
# # Graficos

# %% [markdown]
# ## histograma edades
#
# genera y muestra un histograma con la distribucion de edades de los freelancers.

# %%
plots.graficar_histograma_edades(df)

# %% [markdown]
# conclusion:Aunque es bastante uniforme, resaltan dos picos notorios que superan las 70 personas:
#
#     El pico más alto está justo en los 40-41 años.
#
#     El segundo pico más alto está en el extremo final, alrededor de los 58-60 años.

# %% [markdown]
# ## Grafico de torta (idiomas)
#
# muestra el porcentaje de idiomas que posee cada freelancer.

# %%
plots.graficar_torta_idioma(df)

# %% [markdown]
# El Inglés (21.5%) y el Español (14.2%) concentran juntos más de un tercio de toda la muestra (35.7%). Esto demuestra que, a pesar de haber una gran variedad de idiomas en la plataforma, estos dos son los canales principales de comunicación o los más requeridos para los freelancers.

# %% [markdown]
# ## Matriz de correlacion

# %%
plots.graficar_matriz_correlacion(df)

# %% [markdown]
# Es la correlación más fuerte de todo el gráfico (sacando la diagonal). Tiene todo el sentido del mundo: a mayor edad, por lo general, la persona ha tenido más tiempo para acumular años de experiencia laboral.

# %% [markdown]
# ## Mapa de calor
#
# Mapa de calor de la concentracion de freelancers de su habilidad primaria en su pais correspondiente.

# %%
plots.graficar_mapa_de_calor(df)

# %% [markdown]
# En este caso no existe una correlacion directa entre el pais y la concentracion laboral.

# %% [markdown]
# ## grafico de dispersion e histograma
#
# Dos graficos, uno con la relacion entre la edad de los freelancer vs sus años de experiencia, y el otro una distribucion global de la frecuencia de ratings de los freelancers.

# %%
plots.crear_panel_subgraficos(df)

# %% [markdown]
# En el primer grafico determina que mientras mas edad mayores años de experiencia, por lo que se vuelve mas raro que alguien sea empieze su carrera como freelancer mientras mas edad tenga, en el segundo grtafico la calificacion se encuentra bastante parecida entre si, aunque hay un gran grupo de personas que califica a los freelancers con un punto medio, o que no vota directamente.
